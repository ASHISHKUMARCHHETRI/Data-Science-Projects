# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %% [markdown]
# # Quantile Method

# %%
data=pd.read_csv(r"C:\Mba notes\novels\weight-height.csv")

# %%
data["Gender"]=LabelEncoder().fit_transform(data["Gender"])

# %%
max1=data["Height"].quantile(0.95)

# %%
min1=data["Height"].quantile(0.05)

# %%
df=data[(data["Height"]>min1) & (data["Height"]<max1)]

# %%
print(len(data),len(df))
# Out:
# 10000 9000

# %%
x=df.drop("Gender",axis=1)
y=df.Gender
from sklearn.preprocessing import LabelEncoder

# %%
df["Gender"]=LabelEncoder().fit_transform(df["Gender"])
df
# Out:
# <ipython-input-19-addd2e85f8d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gender"]=LabelEncoder().fit_transform(df["Gender"])
#       Gender     Height      Weight
# 1          1  68.781904  162.310473
# 3          1  71.730978  220.042470
# 4          1  69.881796  206.349801
# 5          1  67.253016  152.212156
# 6          1  68.785081  183.927889
# ...      ...        ...         ...
# 9995       0  66.172652  136.777454
# 9996       0  67.067155  170.867906
# 9997       0  63.867992  128.475319
# 9998       0  69.034243  163.852461
# 9999       0  61.944246  113.649103
#
# [9000 rows x 3 columns]

# %%
cross_val_score(LogisticRegression(),x,y)
# Out:
# array([0.90722222, 0.91666667, 0.90277778, 0.91222222, 0.91722222])

# %%
cross_val_score(LogisticRegression(),data.drop("Gender",axis=1),data.Gender)
# Out:
# array([0.917 , 0.925 , 0.9125, 0.919 , 0.9245])

# %%
data2=pd.read_csv(r"C:\Mba notes\novels\Bengaluru_House_Data.csv")

# %%
data2[:30]
# Out:
#                area_type   availability                  location       size  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1             Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2         Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4   Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5   Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6   Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7   Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8   Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9             Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
# 10  Super built-up  Area         18-Feb                Whitefield      3 BHK
# ...

# %%
data2.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
data2
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
data
# Out:
#       Gender     Height      Weight    result
# 0          1  73.847017  241.893563  0.305287
# 1          1  68.781904  162.310473  0.423768
# 2          1  74.110105  212.740856  0.348359
# 3          1  71.730978  220.042470  0.325987
# 4          1  69.881796  206.349801  0.338657
# ...      ...        ...         ...       ...
# 9995       0  66.172652  136.777454  0.483798
# 9996       0  67.067155  170.867906  0.392509
# 9997       0  63.867992  128.475319  0.497123
# 9998       0  69.034243  163.852461  0.421320
# 9999       0  61.944246  113.649103  0.545048
#
# [10000 rows x 4 columns]

# %%
min1,max1=data.result.quantile([0.01,0.99])

# %%
max1
# Out:
# 0.6101115784215343

# %%
min1
# Out:
# 0.3234455199546822

# %%
df2=data[(data["result"]<max1) & (data["result"]>min1)]

# %%
df2
# Out:
#       Gender     Height      Weight    result
# 1          1  68.781904  162.310473  0.423768
# 2          1  74.110105  212.740856  0.348359
# 3          1  71.730978  220.042470  0.325987
# 4          1  69.881796  206.349801  0.338657
# 5          1  67.253016  152.212156  0.441837
# ...      ...        ...         ...       ...
# 9995       0  66.172652  136.777454  0.483798
# 9996       0  67.067155  170.867906  0.392509
# 9997       0  63.867992  128.475319  0.497123
# 9998       0  69.034243  163.852461  0.421320
# 9999       0  61.944246  113.649103  0.545048
#
# [9800 rows x 4 columns]

# %%
df2.sample
# Out:
# <bound method NDFrame.sample of       Gender     Height      Weight    result
# 1          1  68.781904  162.310473  0.423768
# 2          1  74.110105  212.740856  0.348359
# 3          1  71.730978  220.042470  0.325987
# 4          1  69.881796  206.349801  0.338657
# 5          1  67.253016  152.212156  0.441837
# ...      ...        ...         ...       ...
# 9995       0  66.172652  136.777454  0.483798
# 9996       0  67.067155  170.867906  0.392509
# 9997       0  63.867992  128.475319  0.497123
# 9998       0  69.034243  163.852461  0.421320
# 9999       0  61.944246  113.649103  0.545048
#
# [9800 rows x 4 columns]>

# %% [markdown]
# # z-score,Standard-deviation

# %%
plt.hist(data.Height,bins=20,rwidth=0.8)
# Out:
# (array([   5.,   18.,   66.,  152.,  322.,  604.,  870., 1036., 1117.,
#         1079., 1108., 1059.,  891.,  721.,  510.,  255.,  120.,   43.,
#           19.,    5.]),
#  array([54.26313333, 55.49991378, 56.73669423, 57.97347468, 59.21025513,
#         60.44703558, 61.68381603, 62.92059648, 64.15737693, 65.39415738,
#         66.63093784, 67.86771829, 69.10449874, 70.34127919, 71.57805964,
#         72.81484009, 74.05162054, 75.28840099, 76.52518144, 77.7619619 ,
#         78.99874235]),
#  <a list of 20 Patch objects>)

# %%
from scipy.stats import norm
plt.hist(data.Height,bins=20,rwidth=0.8)
rng=np.arange(data.Height.min(),data.Height.max(),0.3)
plt.plot(rng,norm.pdf(rng,data.Height.mean(),data.Height.std()))

# %%
data.Height.mean()
# Out:
# 66.36755975482106

# %%
data.Height.std()
# Out:
# 3.847528120773233

# %%
ulimit=data.Height.mean() + 3*df.Height.std()
ulimit
# Out:
# 75.86422664124478

# %%
llimit=data.Height.mean() - 3*data.Height.std()
llimit
# Out:
# 54.82497539250136

# %%
data[(data.Height>ulimit) | (data.Height<llimit)]
# Out:
#       Gender     Height      Weight
# 190        1  76.709835  235.035419
# 197        1  75.944460  231.924749
# 232        1  76.021347  235.926061
# 430        1  76.027082  232.313471
# 673        1  76.501883  217.882346
# 741        1  76.012300  235.437966
# 819        1  76.434559  228.872991
# 849        1  76.492934  227.139296
# 912        1  77.160801  228.707301
# 994        1  78.095867  255.690835
# 1096       1  75.999957  224.440459
# 1317       1  78.462053  227.342565
# 1328       1  76.294184  233.503811
# 1568       1  76.456578  239.581389
# 1610       1  76.617546  255.863326
# 1858       1  75.981174  226.474034
# 1896       1  76.472880  246.232321
# 1922       1  77.446620  232.651079
# 1954       1  76.116675  240.638103
# 2014       1  78.998742  269.989699
# 2070       1  77.465569  252.556689
# 2138       1  76.569274  229.858095
# 2318       1  76.806344  227.220343
# 2326       1  75.993360  231.347401
# 2623       1  76.842679  211.724166
# ...

# %%
df1=df[(data.Height<ulimit) & (data.Height>llimit)]
df1.shape
# Out:
# <ipython-input-40-b9f3f40074bc>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df1=df[(data.Height<ulimit) & (data.Height>llimit)]
# (9000, 3)

# %%
data.shape[0]-data.shape[0]
# Out:
# 0

# %%
data["scores"]=(data.Height-data.Height.mean())/data.Height.std()
data.head(5)
# Out:
#    Gender     Height      Weight    scores
# 0       1  73.847017  241.893563  1.943964
# 1       1  68.781904  162.310473  0.627505
# 2       1  74.110105  212.740856  2.012343
# 3       1  71.730978  220.042470  1.393991
# 4       1  69.881796  206.349801  0.913375

# %%
data[(data.scores<-3) | (data.scores>3)]
# Out:
#       Gender     Height      Weight    scores
# 994        1  78.095867  255.690835  3.048271
# 1317       1  78.462053  227.342565  3.143445
# 2014       1  78.998742  269.989699  3.282934
# 3285       1  78.528210  253.889004  3.160640
# 3757       1  78.621374  245.733783  3.184854
# 6624       0  54.616858   71.393749 -3.054091
# 9285       0  54.263133   64.700127 -3.146027

# %% [markdown]
# # Using standard deviation method

# %%
data=pd.read_csv(r"C:\Mba notes\novels\AB_NYC_2019.csv")
data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df4=data[["id","minimum_nights","price"]]

# %%
df4
# Out:
#              id  minimum_nights  price
# 0          2539               1    149
# 1          2595               1    225
# 2          3647               3    150
# 3          3831               1     89
# 4          5022              10     80
# ...         ...             ...    ...
# 48890  36484665               2     70
# 48891  36485057               4     40
# 48892  36485431              10    115
# 48893  36485609               1     55
# 48894  36487245               7     90
#
# [48895 rows x 3 columns]

# %%
df4.isnull().sum()
# Out:
# id                0
# minimum_nights    0
# price             0
# dtype: int64

# %%
df4["price/night"]=data.price/data.minimum_nights
# Out:
# <ipython-input-10-f0720564abec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4["price/night"]=data.price/data.minimum_nights

# %%
df4
# Out:
#              id  minimum_nights  price  price/night
# 0          2539               1    149   149.000000
# 1          2595               1    225   225.000000
# 2          3647               3    150    50.000000
# 3          3831               1     89    89.000000
# 4          5022              10     80     8.000000
# ...         ...             ...    ...          ...
# 48890  36484665               2     70    35.000000
# 48891  36485057               4     40    10.000000
# 48892  36485431              10    115    11.500000
# 48893  36485609               1     55    55.000000
# 48894  36487245               7     90    12.857143
#
# [48895 rows x 4 columns]

# %%
min1,max1=df4["price/night"].quantile(0.05),df4["price/night"].quantile(0.95)
# Out:
# 200.0

# %%
df5=df4[(df4["price/night"]>min1) & (df4["price/night"]<max1)]

# %%
df5
# Out:
#              id  minimum_nights  price  price/night
# 0          2539               1    149   149.000000
# 2          3647               3    150    50.000000
# 3          3831               1     89    89.000000
# 4          5022              10     80     8.000000
# 5          5099               3    200    66.666667
# ...         ...             ...    ...          ...
# 48890  36484665               2     70    35.000000
# 48891  36485057               4     40    10.000000
# 48892  36485431              10    115    11.500000
# 48893  36485609               1     55    55.000000
# 48894  36487245               7     90    12.857143
#
# [43889 rows x 4 columns]

# %%
ulimit=df4["price/night"].mean()+3*df4["price/night"].std()

# %%
llimit=df4["price/night"].mean()-3*df4["price/night"].std()

# %%
df5=df4[(df4["price/night"]<ulimit) & (df4["price/night"]>llimit)]

# %%
df5
# Out:
#              id  minimum_nights  price  price/night
# 0          2539               1    149   149.000000
# 1          2595               1    225   225.000000
# 2          3647               3    150    50.000000
# 3          3831               1     89    89.000000
# 4          5022              10     80     8.000000
# ...         ...             ...    ...          ...
# 48890  36484665               2     70    35.000000
# 48891  36485057               4     40    10.000000
# 48892  36485431              10    115    11.500000
# 48893  36485609               1     55    55.000000
# 48894  36487245               7     90    12.857143
#
# [48589 rows x 4 columns]

# %%
df4["z_score"]=(df4["price/night"]-df4["price/night"].mean())/df4["price/night"].std()
# Out:
# <ipython-input-39-b96c7e201e8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4["z_score"]=(df4["price/night"]-df4["price/night"].mean())/df4["price/night"].std()

# %%
z_score
# Out:
# 0        0.500099
# 1        0.982270
# 2       -0.127993
# 3        0.119437
# 4       -0.394456
#            ...
# 48890   -0.223158
# 48891   -0.381767
# 48892   -0.372250
# 48893   -0.096271
# 48894   -0.363640
# Name: price/night, Length: 48895, dtype: float64

# %%
df5=df4[(df4["z_score"]<3) & df4["z_score"]>-3]

# %%
df5
# Out:
#              id  minimum_nights  price  price/night   z_score
# 0          2539               1    149   149.000000  0.500099
# 1          2595               1    225   225.000000  0.982270
# 2          3647               3    150    50.000000 -0.127993
# 3          3831               1     89    89.000000  0.119437
# 4          5022              10     80     8.000000 -0.394456
# ...         ...             ...    ...          ...       ...
# 48890  36484665               2     70    35.000000 -0.223158
# 48891  36485057               4     40    10.000000 -0.381767
# 48892  36485431              10    115    11.500000 -0.372250
# 48893  36485609               1     55    55.000000 -0.096271
# 48894  36487245               7     90    12.857143 -0.363640
#
# [48895 rows x 5 columns]

# %%
df5.describe()
# Out:
#                  id  minimum_nights         price   price/night       z_score
# count  4.889500e+04    48895.000000  48895.000000  48895.000000  4.889500e+04
# mean   1.901714e+07        7.029962    152.720687     70.174247  5.321070e-15
# std    1.098311e+07       20.510550    240.154170    157.620388  1.000000e+00
# min    2.539000e+03        1.000000      0.000000      0.000000 -4.452105e-01
# 25%    9.471945e+06        1.000000     69.000000     20.000000 -3.183233e-01
# 50%    1.967728e+07        3.000000    106.000000     44.500000 -1.628866e-01
# 75%    2.915218e+07        5.000000    175.000000     81.500000  7.185462e-02
# max    3.648724e+07     1250.000000  10000.000000   8000.000000  5.030965e+01

# %%
Q3=df5["price/night"].quantile(0.75)
Q1=df5["price/night"].quantile(0.25)

# %%
IQR=Q3-Q1

# %%
ulimit=Q1+1.5*IQR
llimit=Q3+1.5*IQR

# %%
ulimit
# Out:
# 112.25

# %%
llimit
# Out:
# 173.75

# %%
df6=df5[(df5["price/night"]>ulimit) & df5["price/night"]<llimit]

# %%
df6
# Out:
#              id  minimum_nights  price  price/night   z_score
# 0          2539               1    149   149.000000  0.500099
# 1          2595               1    225   225.000000  0.982270
# 2          3647               3    150    50.000000 -0.127993
# 3          3831               1     89    89.000000  0.119437
# 4          5022              10     80     8.000000 -0.394456
# ...         ...             ...    ...          ...       ...
# 48890  36484665               2     70    35.000000 -0.223158
# 48891  36485057               4     40    10.000000 -0.381767
# 48892  36485431              10    115    11.500000 -0.372250
# 48893  36485609               1     55    55.000000 -0.096271
# 48894  36487245               7     90    12.857143 -0.363640
#
# [48895 rows x 5 columns]
