# %%
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\credit.csv")

# %%
data.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0    20000.0    2          2         1   24      2      2     -1     -1
# 1   120000.0    2          2         2   26     -1      2      0      0
# 2    90000.0    2          2         2   34      0      0      0      0
# 3    50000.0    2          2         1   37      0      0      0      0
# 4    50000.0    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# ...

# %%
sns.relplot(x="EDUCATION",y="default_payment_next_month",data=data,kind="line")

# %%
sns.barplot(x="EDUCATION",y="default_payment_next_month",data=data)

# %%
sns.catplot(x="MARRIAGE",y="default_payment_next_month",data=data,kind="bar")

# %%
sns.catplot(x="MARRIAGE",y="default_payment_next_month",data=data,kind="boxen")

# %%
c=np.random.normal(loc=5,size=100,scale=3)

# %%
sns.distplot(c)

# %%
a=sns.FacetGrid(data,row="default_payment_next_month",col="SEX") 
a=a.map(plt.hist,"MARRIAGE")

# %%
a=sns.FacetGrid(data,row="default_payment_next_month",col="EDUCATION")
a=a.map(plt.hist,"MARRIAGE")

# %%
sns.set(style="darkgrid")
a=sns.FacetGrid(data,row="default_payment_next_month",col="SEX")
a=a.map(plt.hist,"MARRIAGE")

# %%
sns.set(style="dark")
a=sns.FacetGrid(data,row="default_payment_next_month",col="SEX")
a=a.map(plt.hist,"MARRIAGE")

# %%
sns.boxplot(x="SEX",y="MARRIAGE",data=data)

# %%
sns.set(style="white",color_codes=True)
sns.boxplot(x="EDUCATION",y="MARRIAGE",data=data)

# %%
sns.set(style="white",color_codes=True)
sns.boxplot(x="EDUCATION",y="MARRIAGE",data=data)
sns.despine(offset=10,trim=True)

# %%
c=sns.color_palette()
sns.palplot(c)

# %%
from sklearn.datasets import load_iris
iris=load_iris()
pd.DataFrame(iris.data,columns=iris.feature_names)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
data=pd.read_csv(r"C:\Mba notes\novels\500_Person_Gender_Height_Weight_Index.csv")

# %%
sns.countplot(data["Bmi"].sort_values())

# %%
sns.distplot(data["Bmi"])

# %%
plt.figure(figsize=(15,8))
df1=data.copy()
df1["Height"]=pd.cut(df1["Height"],[140,150,160,170,180,190,200],labels=["140-150","150-160","160-170","170-180","180-190","190-200"])
sns.boxplot(x="Height",y="Bmi",data=df1)

# %%
sns.jointplot(x="Height",y="Bmi",data=data,ratio=3,color="y")

# %%
df1["Weight"].max(),df1["Weight"].min()
# Out:
# (160, 50)

# %%
df1=data.copy()
plt.figure(figsize=(12,8))
df1["Weight"]=pd.cut(df1["Weight"],[50,70,90,110,130,150,170],labels=["50-70","70-90","90-110","110-130","130-150","150-170"])
sns.pointplot(x="Weight",y="Bmi",data=df1,color="lime")
plt.xlabel("Weight",fontsize=14,color="yellow")
plt.ylabel("BMI",fontsize=14,color="green")
plt.title("Weight-Height Graph")
# Out:
# Text(0.5, 1.0, 'Weight-Height Graph')

# %%
df1=data.copy()
plt.figure(figsize=(12,8))
df1["Height"]=pd.cut(df1["Height"],[140,150,160,170,180,190,200],labels=["140-150","150-160","160-170","170-180","180-190","190-200"])
df1["Weight"]=pd.cut(df1["Weight"],[50,70,90,110,130,150,170],labels=["50-70","70-90","90-110","110-130","130-150","150-170"])
sns.pointplot(x="Height",y="Bmi",data=df1,color="blue",alpha=0.9)
sns.pointplot(x="Weight",y="Bmi",data=df1,color="black",alpha=0.5)
plt.text(6,0.8,"HEIGHT",color="blue",style="italic")
plt.text(6,0.8,"WEIGHT",color="black",style="italic")
plt.show()

# %%
df1
# Out:
#      Gender   Height   Weight  Bmi
# 0      Male  170-180   90-110    4
# 1      Male  180-190    70-90    2
# 2    Female  180-190   90-110    4
# 3    Female  190-200   90-110    3
# 4      Male  140-150    50-70    3
# ..      ...      ...      ...  ...
# 495  Female  140-150  150-170    5
# 496  Female  180-190  110-130    4
# 497  Female  140-150  130-150    5
# 498    Male  140-150   90-110    5
# 499    Male  170-180  130-150    5
#
# [500 rows x 4 columns]

# %%
sns.jointplot("Height","Bmi",data=data,ratio=3,height=10,color="orange")

# %%
f,ax1=plt.subplots(figsize=(15,8))
sns.pointplot(x="Weight",y="Bmi",data=df1,color="lime",alpha=0.8)
sns.pointplot(x="Height",y="Bmi",data=df1,color="blue",alpha=0.8)
plt.text(4,0.6,"Heals",color="lime",fontsize=16,style="italic")
plt.text(4,0.55,"Boosts",color="blue",fontsize=16,style="italic")
# Out:
# Text(4, 0.55, 'Boosts')

# %%
sns.countplot(data["Gender"])

# %%
data
# Out:
#      Gender  Height  Weight  Bmi
# 0      Male     174      96    4
# 1      Male     189      87    2
# 2    Female     185     110    4
# 3    Female     195     104    3
# 4      Male     149      61    3
# ..      ...     ...     ...  ...
# 495  Female     150     153    5
# 496  Female     184     121    4
# 497  Female     141     136    5
# 498    Male     150      95    5
# 499    Male     173     131    5
#
# [500 rows x 4 columns]

# %%
data["Height/Bmi"]=(data["Height"]/data["Bmi"]).rank(pct=True).values
data
# Out:
#      Gender  Height  Weight  Bmi  Height/Bmi
# 0      Male     174      96    4       0.518
# 1      Male     189      87    2       0.910
# 2    Female     185     110    4       0.579
# 3    Female     195     104    3       0.786
# 4      Male     149      61    3       0.662
# ..      ...     ...     ...  ...         ...
# 495  Female     150     153    5       0.106
# 496  Female     184     121    4       0.574
# 497  Female     141     136    5       0.021
# 498    Male     150      95    5       0.106
# 499    Male     173     131    5       0.311
#
# [500 rows x 5 columns]

# %%
# Out:
#      Gender  Height  Weight  Bmi  Height/Bmi
# 0      Male     174      96    4       0.518
# 1      Male     189      87    2       0.910
# 2    Female     185     110    4       0.579
# 3    Female     195     104    3       0.786
# 4      Male     149      61    3       0.662
# ..      ...     ...     ...  ...         ...
# 495  Female     150     153    5       0.106
# 496  Female     184     121    4       0.574
# 497  Female     141     136    5       0.021
# 498    Male     150      95    5       0.106
# 499    Male     173     131    5       0.311
#
# [500 rows x 5 columns]
